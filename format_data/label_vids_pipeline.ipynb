# %%
import os
basedir = "D:\\new_pig_data\\cage2\\2019-04-02\\video"
indir = os.path.join(basedir,"00_03")
outdir = "D:\\Google Drive\\Pig Labeled Frames\\cage2"
labels = os.path.join(basedir,'cage2_2019040200.tsv')
vid_paths = os.path.join(basedir,'video_lengths00.txt')

#%run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 

indir = os.path.join(basedir,"04_07")
labels = os.path.join(basedir,'cage2_2019040204.tsv')
vid_paths = os.path.join(basedir,'video_lengths04.txt')

#%run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040208.tsv')
vid_paths = os.path.join(basedir,'video_lengths08.txt')
indir = os.path.join(basedir,"08_11")

#%run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040212.tsv')
vid_paths = os.path.join(basedir,'video_lengths12.txt')
indir = os.path.join(basedir,"12_15")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040216.tsv')
vid_paths = os.path.join(basedir,'video_lengths16.txt')
indir = os.path.join(basedir,"16_19")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040220.tsv')
vid_paths = os.path.join(basedir,'video_lengths20.txt')
indir = os.path.join(basedir,"20_23")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths
# Out:
# -------  -------
# ------- run time: section: 0 hours, 0 minutes, 0 seconds, total: 0 hours, 0 minutes, 0 seconds -------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Box Sync\Code\Pigs\label_vids.py in <module>
#     232     set_opts(args=sys.argv[1:])
#     233     print_elapsed_time()
# --> 234     main()
#     235     print_elapsed_time('end program')
#
# ~\Box Sync\Code\Pigs\label_vids.py in main()
#     200     is_nursing = False
#     201     labeling_started = False
# --> 202     vid = open_new_video(0)
#     203     frame_i = 0
#     204     cur_time = 0
#
# ~\Box Sync\Code\Pigs\label_vids.py in open_new_video(vid_i)
#     141
#     142 def open_new_video(vid_i):
# --> 143     info = vid_list[vid_i]
#     144     cap = cv2.VideoCapture(os.path.join(indir,info.name))
#     145     # Check if camera opened successfully
#
# ...

# %%
basedir = "D:\\new_pig_data\\cage2\\2019-04-03\\videos"
indir = os.path.join(basedir,"00_03")
outdir = "D:\\Google Drive\\Pig Labeled Frames\\cage2"
labels = os.path.join(basedir,'cage2_2019040300.tsv')
vid_paths = os.path.join(basedir,'video_lengths00.txt')

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 

indir = os.path.join(basedir,"04_07")
labels = os.path.join(basedir,'cage2_2019040304.tsv')
vid_paths = os.path.join(basedir,'video_lengths04.txt')

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040308.tsv')
vid_paths = os.path.join(basedir,'video_lengths08.txt')
indir = os.path.join(basedir,"08_11")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040312.tsv')
vid_paths = os.path.join(basedir,'video_lengths12.txt')
indir = os.path.join(basedir,"12_15")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040316.tsv')
vid_paths = os.path.join(basedir,'video_lengths16.txt')
indir = os.path.join(basedir,"16_19")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


labels = os.path.join(basedir,'cage2_2019040320.tsv')
vid_paths = os.path.join(basedir,'video_lengths20.txt')
indir = os.path.join(basedir,"20_23")

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths

# %%
basedir = "D:\\new_pig_data\\cage4\\2019-04-26\\videos"
indir = os.path.join(basedir,"00_23")
outdir = "D:\\Google Drive\\Pig Labeled Frames\\cage4\\pregnant_sow"
labels = os.path.join(basedir,'20190426.tsv')
vid_paths = os.path.join(basedir,'video_lengths.txt')

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 


basedir = "D:\\new_pig_data\\cage4\\2019-04-27\\videos"
indir = os.path.join(basedir,"00_23")
outdir = "D:\\Google Drive\\Pig Labeled Frames\\cage4\\pregnant_sow"
labels = os.path.join(basedir,'20190427.tsv')
vid_paths = os.path.join(basedir,'video_lengths.txt')

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths 



basedir = "D:\\new_pig_data\\cage4\\2019-04-28\\videos"
indir = os.path.join(basedir,"00_23")
outdir = "D:\\Google Drive\\Pig Labeled Frames\\cage4\\pregnant_sow"
labels = os.path.join(basedir,'20190428.tsv')
vid_paths = os.path.join(basedir,'video_lengths.txt')

# %run label_vids.py --in_dir=$indir --out_dir=$outdir --label_file=$labels --vid_path_list=$vid_paths
